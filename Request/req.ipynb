# %%
import requests
from bs4 import BeautifulSoup
import json
from httpx import AsyncClient
import sqlite3
from urllib import request

# %%
proxies={
'http': 'http://127.0.0.1:7890',
'https': 'http://127.0.0.1:7890'
}

# %%
USER_AGENT = "PixivAndroidApp/5.0.234 (Android 11; Pixel 5)"
AUTH_TOKEN_URL = "https://oauth.secure.pixiv.net/auth/token"
CLIENT_ID = "MOBrBDS8blbauoSck0ZfDbtuzpyT"
CLIENT_SECRET = "lsACyCD94FhDUtGTXi3QzcFE2uU1hqtDaKeqrdwj"
data = {
            "client_id": CLIENT_ID,
            "client_secret": CLIENT_SECRET,
            "grant_type": "refresh_token",
            "include_policy": "true",
            "refresh_token": "Ia5yMu1_sYs72r-HSgJ4T3jQArXgfdsk3_iGTAM3O5c",
        }

# %%
res = requests.post(url=AUTH_TOKEN_URL,data=data,headers={"User-Agent": USER_AGENT},proxies=proxies)
print(res.status_code)
html = BeautifulSoup(res.text,'html.parser')

# %%
import requests
import re
import json

data = {
    "prompt": "masterpiece, best quality, extremely detailed 4k CG,Long lightblue hair,one small golden flower ornaments, blue eyes, royal sister, cold face and white shirt",
    "width": 512,
    "height": 768,
    "scale": 12,
    "sampler": "k_euler_ancestral",
    "steps": 28,
    "seed": 2113871028,
    "n_samples": 1,
    "ucPreset": 0,
    "uc": "lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry",
}

res = requests.post("http://127.0.0.1:6969/generate-stream", json=data)
# text = json.loads(res.text)
print(res.text)
# Out:
# event: newImage
# id: 1
# data:...

# %%
import re
result = re.findall(r"(?<=data:)[A-Za-z0-9]*", res.text)

# %%
index = res.text.find("data:")
print(result[0]==res.text[index+5:])
# Out:
# False

# %%
import base64
print(result[0])
print(base64.b64decode(res.text[index+5:]))

# %%
import os
with open(f"{os.getcwd()}/1.jpg", "wb") as f:
    f.write(base64.b64decode(res.text[index+5:]))
    f.close()
